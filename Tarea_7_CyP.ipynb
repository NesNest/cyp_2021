# %% [markdown]
# <a href="https://colab.research.google.com/github/PlasticTramp/cyp_2021/blob/main/Tarea_7_CyP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#problema 4.11
print("Ingrése el número de países por región ")
pcen = int(input("Región Centro "))
psur = int(input("Región Sur "))
pnor = int(input("Región Norte "))
sur = [0.0 for x in range(psur)]
cen = [0.0 for x in range(pcen)]
nor = [0.0 for x in range(pnor)]
ame = [0.0 for x in range(pcen + psur + pnor + 3)]
if (pcen <= 30) and (pnor <= 30) and (psur <= 30) and (1 <= pcen) and (1 <= pnor) and (1 <= psur):
  print("Ingrese los nombres de los paises de Centroamerica")
  for i in range(pcen):
    cen[i] = str(input(f"{i + 1}. "))
    i = i + 1
  print("Ingrese los nombres de los paises de Suramerica")
  for i in range(psur):
    sur[i] = str(input(f"{i + 1}. "))
    i = i + 1
  print("Ingrese los nombres de los paises de Norteamerica")
  for i in range(pnor):
    nor[i] = str(input(f"{i + 1}. "))
    i = i + 1
  ps = 0
  pn = 0
  pc = 0
  pa = 0
  while (ps != psur) and (pc != pcen) and (pn != pnor):
    pa = pa + 1
    if (sur[ps] < cen[pc]) and (sur[ps] < nor[pn]):
      ame[pa] = sur[ps]
      ps = ps + 1 
    else:
      if cen[pc] < nor[pn]:
        ame[pa] = cen[pc]
        pc = pc + 1
      else:
        ame[pa] = nor[pn]
        pn = pn + 1
  while (ps != psur) and (pc != pcen):
    pa = pa + 1
    if sur[ps] < cen[pc]:
      ame[pa] = sur[ps]
      ps = ps + 1
    else:
      ame[pa] = cen[pc]
      pc = pc + 1
  while (ps != psur) and (pn != pnor):
    pa = pa + 1 
    if sur[ps] < nor[pn]:
      ame[pa] = sur[ps]
      ps = ps + 1
    else:
      ame[pa] = nor[pn]
      pn = pn + 1     
  while (pc != pcen) and (pn != pnor):
    pa = pa + 1
    if cen[pc] < nor[pn]:
      ame[pa] = cen[pc]
      pc = pc + 1
    else:
      ame[pa] = nor[pn]
      pn = pn + 1
  while ps != psur:
    pa = pa + 1
    ame[pa] = sur[ps]
    ps = ps + 1
  while pc != pcen:
    pa = pa + 1
    ame[pa] = cen[pc]
    pc = pc + 1
  while pn != pnor:
    pa = pa + 1
    ame[pa] = nor[pn]
    pn = pn + 1
  i = 1
  print("Arreglo America")
  for i in range(pa):
    print(str(i + 1) + ". " + str(ame[i + 1]))
    i = i + 1
else:
  print("Verifique el número de países")
# Out:
# Ingrése el número de países por región
# Región Centro 7
# Región Sur 12
# Región Norte 3
# Ingrese los nombres de los paises de Centroamerica
# 1. Belice
# 2. Costa Rica
# 3. El Salvador
# 4. Guatemala
# 5. Honduras
# 6. Nicaragua
# 7. Panama
# Ingrese los nombres de los paises de Suramerica
# 1. Argentina
# 2. Bolivia
# 3. Brasil
# 4. Chile
# 5. Colombia
# 6. Ecuador
# 7. Guyana
# 8. Paraguay
# 9. Peru
# 10. Surinam
# 11. Uruguay
# 12. Venezuela
# Ingrese los nombres de los paises de Norteamerica
# 1. Canada
# 2. E.U.
# 3. México
# Arreglo America
# 1. Argentina
# 2. Belice
# 3. Bolivia
# 4. Brasil
# 5. Canada
# 6. Chile
# 7. Colombia
# 8. Costa Rica
# 9. E.U.
# 10. Ecuador
# 11. El Salvador
# 12. Guatemala
# 13. Guyana
# 14. Honduras
# 15. México
# 16. Nicaragua
# 17. Panama
# 18. Paraguay
# 19. Peru
# 20. Surinam
# 21. Uruguay
# 22. Venezuela
