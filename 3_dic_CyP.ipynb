# %% [markdown]
# <a href="https://colab.research.google.com/github/PlasticTramp/cyp_2021/blob/main/3_dic_CyP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#ejemplo 1
for i in[1,2,3,4,5]:
  print(f"el elmento {i}")
# Out:
# el elmento 1
# el elmento 2
# el elmento 3
# el elmento 4
# el elmento 5

# %%
coleccion = [1,2,3,4,5]
for i in coleccion:
   print(f"el elmento {i}")
# Out:
# el elmento 1
# el elmento 2
# el elmento 3
# el elmento 4
# el elmento 5

# %%
#ejemplo 2
coleccion = {"mario":20,"Mariana":19,"Yessica":14,"Luis":18}
for i in coleccion:
  print(f"elemento: {i}")
# Out:
# elemento: mario
# elemento: Mariana
# elemento: Yessica
# elemento: Luis

# %%
coleccion = {"mario":20,"Mariana":19,"Yessica":14,"Luis":18}
for i in coleccion:
  print(f"{i}")
# Out:
# mario
# Mariana
# Yessica
# Luis

# %%
coleccion = {"mario":20,"Mariana":19,"Yessica":14,"Luis":18}
for i in coleccion:
  print(f"{coleccion [i]}")
# Out:
# 20
# 19
# 14
# 18

# %%
coleccion = {"mario":20,"Mariana":19,"Yessica":14,"Luis":18}
for i in coleccion:
  print(f"{i}->{coleccion[i]}")
# Out:
# mario-->20
# Mariana-->19
# Yessica-->14
# Luis-->18

# %%
coleccion = {"mario":20,"Mariana":19,"Yessica":14,"Luis":18}
for clave, valor in coleccion.items():
  print(f"{clave}->{valor}")
# Out:
# mario, 20
# Mariana, 19
# Yessica, 14
# Luis, 18

# %%
#ejemplpo 3
email = False
for i in "email":
 if (i == "@"):
  email = True
if (email == True):
  print("email correcto")
else:
  print("correo incorrecto")
# Out:
# correo incorrecto

# %%
email = False
mima = input("ingresa el correo ")
for i in mima:
  if (i == "@"):
    email = True
if (email == True):
   print("email correcto")
else:
  print("correo no valido")
# Out:
# ingresa el correo sadf
# correo incorrecto

# %%
#for-range 
for i in range (5):
  print("hola")
# Out:
# 1
# 1
# 1
# 1
# 1

# %%
for i in range (5):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range (20):
  print(f"valor de la variable {i}")
# Out:
# valor de la variable 0
# valor de la variable 1
# valor de la variable 2
# valor de la variable 3
# valor de la variable 4
# valor de la variable 5
# valor de la variable 6
# valor de la variable 7
# valor de la variable 8
# valor de la variable 9
# valor de la variable 10
# valor de la variable 11
# valor de la variable 12
# valor de la variable 13
# valor de la variable 14
# valor de la variable 15
# valor de la variable 16
# valor de la variable 17
# valor de la variable 18
# valor de la variable 19

# %%
#while ejemplo 1
i = 1
while i <= 10:
  print("ejecucion " + str(i))
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ejecucion 1
# ...

# %%
i = 1
while i <= 10:
  print("ejecucion " + str(i))

  i = i + 1 #contador
# Out:
# ejecucion 1
# ejecucion 2
# ejecucion 3
# ejecucion 4
# ejecucion 5
# ejecucion 6
# ejecucion 7
# ejecucion 8
# ejecucion 9
# ejecucion 10

# %%
edad = int(input("introduce la edad"))
while edad < 0:
  print("has introducido una edad invalida")
  edad = int(input("ya pon tu edad real "))
print("gracias por participar")
print("edad " + str(edad))
# Out:
# introduce la edad123
# gracias por participar
# edad123

# %%
edad = int(input("introduce la edad"))
while edad < 0 or edad >= 100:
  print("has introducido una edad invalida")
  edad = int(input("ya pon tu edad real "))
print("gracias por participar")
print("edad " + str(edad))
# Out:
# introduce la edad3456
# has introducido una edad invalida
# ya pon tu edad real234
# has introducido una edad invalida
# ya pon tu edad real234
# has introducido una edad invalida
# ya pon tu edad real3456
# has introducido una edad invalida
# ya pon tu edad real12
# gracias por participar
# edad 12
